# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
# to avoid warnings
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %%
# link to import data
data_url="https://www.berlin.de/sen/uvk/_assets/verkehr/infrastruktur/oeffentliche-toiletten/berliner-toiletten-standorte.xlsx"

# %% [markdown]
# ## Importing data from source

# %%
data = pd.read_excel(data_url)

# %% [markdown]
# ## Viewing data

# %%
data.head()
# Out:
#   Stand:27.04.2022                                         Unnamed: 1  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2       LavatoryID                                        Description
# 3      Wall_101003  Toilette Ottmachauer Steig (oberhalb Badestell...
# 4      Wall_112911                                  Toilette Uferweg
#
#   Unnamed: 2                                         Unnamed: 3 Unnamed: 4  \
# 0        NaN                                                NaN        NaN
# 1        NaN                                                NaN        NaN
# 2       City                                             Street     Number
# 3     Berlin            Krumme Lanke, Quermatenweg   (0-24 Uhr)        NaN
# 4     Berlin  Schlachtensee , Am Schlachtensee ggü. 145  (0-...        NaN
#
#    Unnamed: 5   Unnamed: 6        Unnamed: 7        Unnamed: 8     Unnamed: 9  \
# 0         NaN          NaN               NaN               NaN            NaN
# 1         NaN          NaN               NaN               NaN            NaN
# 2  PostalCode      Country         Longitude          Latitude  isOwnedByWall
# 3       14109  Deutschland      13,240574813      52,453581173              1
# 4       14129  Deutschland  13,1992287644287  52,4365068880875              1
#
#                Unnamed: 10 Unnamed: 11          Unnamed: 12      Unnamed: 13  \
# 0                      NaN         NaN                  NaN              NaN
# 1                      NaN         NaN                  NaN              NaN
# 2  isHandicappedAccessible       Price  canBePayedWithCoins  canBePayedInApp
# 3                        0        0,00                    0                0
# 4                        0        0,00                    0                0
#
#          Unnamed: 14       Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18
# 0                NaN               NaN         NaN         NaN         NaN
# 1                NaN               NaN         NaN         NaN         NaN
# 2  canBePayedWithNFC  hasChangingTable     LabelID   hasUrinal         FID
# 3                  0                 0           5           0         269
# 4                  0                 0           5           0         NaN

# %% [markdown]
# ## Fixing data structure

# %%
# Making row 2 the column headings
data.columns = data.iloc[2]

# %%
data.head()
# Out:
# 2   LavatoryID                                        Description    City  \
# 0          NaN                                                NaN     NaN
# 1          NaN                                                NaN     NaN
# 2   LavatoryID                                        Description    City
# 3  Wall_101003  Toilette Ottmachauer Steig (oberhalb Badestell...  Berlin
# 4  Wall_112911                                  Toilette Uferweg   Berlin
#
# 2                                             Street  Number  PostalCode  \
# 0                                                NaN     NaN         NaN
# 1                                                NaN     NaN         NaN
# 2                                             Street  Number  PostalCode
# 3            Krumme Lanke, Quermatenweg   (0-24 Uhr)     NaN       14109
# 4  Schlachtensee , Am Schlachtensee ggü. 145  (0-...     NaN       14129
#
# 2      Country         Longitude          Latitude  isOwnedByWall  \
# 0          NaN               NaN               NaN            NaN
# 1          NaN               NaN               NaN            NaN
# 2      Country         Longitude          Latitude  isOwnedByWall
# 3  Deutschland      13,240574813      52,453581173              1
# 4  Deutschland  13,1992287644287  52,4365068880875              1
#
# 2  isHandicappedAccessible  Price  canBePayedWithCoins  canBePayedInApp  \
# 0                      NaN    NaN                  NaN              NaN
# 1                      NaN    NaN                  NaN              NaN
# 2  isHandicappedAccessible  Price  canBePayedWithCoins  canBePayedInApp
# 3                        0   0,00                    0                0
# 4                        0   0,00                    0                0
#
# 2  canBePayedWithNFC  hasChangingTable  LabelID  hasUrinal  FID
# 0                NaN               NaN      NaN        NaN  NaN
# 1                NaN               NaN      NaN        NaN  NaN
# 2  canBePayedWithNFC  hasChangingTable  LabelID  hasUrinal  FID
# 3                  0                 0        5          0  269
# 4                  0                 0        5          0  NaN

# %%
# dropping redundant rows
data.drop([0,1,2],inplace=True)

# %% [markdown]
# ## Exploring data

# %%
data.shape
# Out:
# (440, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440 entries, 3 to 442
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LavatoryID               440 non-null    object
#  1   Description              440 non-null    object
#  2   City                     440 non-null    object
#  3   Street                   440 non-null    object
#  4   Number                   0 non-null      object
#  5   PostalCode               440 non-null    object
#  6   Country                  440 non-null    object
#  7   Longitude                440 non-null    object
#  8   Latitude                 440 non-null    object
#  9   isOwnedByWall            440 non-null    object
#  10  isHandicappedAccessible  440 non-null    object
#  11  Price                    440 non-null    object
#  12  canBePayedWithCoins      440 non-null    object
#  13  canBePayedInApp          440 non-null    object
#  14  canBePayedWithNFC        440 non-null    object
#  15  hasChangingTable         440 non-null    object
#  16  LabelID                  440 non-null    object
#  17  hasUrinal                440 non-null    object
#  18  FID                      349 non-null    object
# dtypes: object(19)
# memory usage: 68.8+ KB

# %% [markdown]
# ## Exploring missing data

# %%
data.isnull().sum()
# Out:
# 2
# LavatoryID                   0
# Description                  0
# City                         0
# Street                       0
# Number                     440
# PostalCode                   0
# Country                      0
# Longitude                    0
# Latitude                     0
# isOwnedByWall                0
# isHandicappedAccessible      0
# Price                        0
# canBePayedWithCoins          0
# canBePayedInApp              0
# canBePayedWithNFC            0
# hasChangingTable             0
# LabelID                      0
# hasUrinal                    0
# FID                         91
# dtype: int64

# %%
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Since FID is an external identification number and does not affect our app we leave the missing numbers
# ##### Number Column is the House number/Location, since all the values are missing and the location can also be detected using the lattitude and longitude columns we will leave the missing values as they are

# %% [markdown]
# ## Extracting opening hours and address from Street column

# %%
df1=pd.DataFrame({'Street':data['Street']})
df1[['address','timings']]=df1['Street'].str.split('(',n=1,expand=True)
df1['timings']=df1['timings'].str.extract('([0-9]+-[0-9]+)')
df1[['opening_hour','closing_hour']]=df1['timings'].str.split("-",n=1,expand=True)
data['opening_hours']=df1['opening_hour']+str(':00')+str('-')+df1['closing_hour']+str(':00')
data['street_address']=df1['address']
data=data[['LavatoryID', 'Description', 'City', 'Street','opening_hours', 'street_address', 'Number', 'PostalCode',
       'Country', 'Longitude', 'Latitude', 'isOwnedByWall',
       'isHandicappedAccessible', 'Price', 'canBePayedWithCoins',
       'canBePayedInApp', 'canBePayedWithNFC', 'hasChangingTable', 'LabelID',
       'hasUrinal', 'FID' ]]

# %%
# Deleting Number column as it add no value
data.drop('Number', axis=1, inplace=True)
data.drop('FID', axis=1, inplace=True)

# %%
data.head()
# Out:
# 2   LavatoryID                                        Description    City  \
# 3  Wall_101003  Toilette Ottmachauer Steig (oberhalb Badestell...  Berlin
# 4  Wall_112911                                  Toilette Uferweg   Berlin
# 5  Wall_115753                           Toilette Am Kiesteich 50  Berlin
# 6  Wall_116738                              Wall CT, Hubertusdamm  Berlin
# 7  Wall_116739                                Wall CT, Lindenufer  Berlin
#
# 2                                             Street opening_hours  \
# 3            Krumme Lanke, Quermatenweg   (0-24 Uhr)    0:00-24:00
# 4  Schlachtensee , Am Schlachtensee ggü. 145  (0-...    0:00-24:00
# 5                            Spektepark   (0-24 Uhr)    0:00-24:00
# 6                     Hubertusdamm ggü. 7 (0-24 Uhr)    0:00-24:00
# 7                      Lindenufer ggü. 10 (0-24 Uhr)    0:00-24:00
#
# 2                               street_address PostalCode      Country  \
# 3                Krumme Lanke, Quermatenweg         14109  Deutschland
# 4  Schlachtensee , Am Schlachtensee ggü. 145        14129  Deutschland
# 5                                Spektepark         13589  Deutschland
# 6                         Hubertusdamm ggü. 7       13125  Deutschland
# 7                          Lindenufer ggü. 10       13597  Deutschland
#
# 2         Longitude          Latitude isOwnedByWall isHandicappedAccessible  \
# 3      13,240574813      52,453581173             1                       0
# 4  13,1992287644287  52,4365068880875             1                       0
# 5  13,1648593254089  52,5488398803196             1                       0
# 6  13,4711982596938   52,615670613826             1                       1
# 7  13,2077640060379   52,537351114776             1                       1
#
# 2 Price canBePayedWithCoins canBePayedInApp canBePayedWithNFC  \
# 3  0,00                   0               0                 0
# 4  0,00                   0               0                 0
# 5  0,00                   0               0                 0
# 6  0,50                   1               1                 1
# 7  0,50                   1               1                 1
#
# 2 hasChangingTable LabelID hasUrinal
# 3                0       5         0
# 4                0       5         0
# 5                0       5         0
# 6                1       1         1
# 7                1       1         0

# %%
#Replacing values to make more sense
data["isOwnedByWall"] = data["isOwnedByWall"].replace(to_replace=[1, 0], value=["Yes", "No"])
data["isHandicappedAccessible"] = data["isHandicappedAccessible"].replace(to_replace=[1, 0], value=["Yes", "No"])
data["canBePayedWithCoins"] = data["canBePayedWithCoins"].replace(to_replace=[1, 0], value=["Yes", "No"])
data["canBePayedInApp"] = data["canBePayedInApp"].replace(to_replace=[1, 0], value=["Yes", "No"])
data["canBePayedWithNFC"] = data["canBePayedWithNFC"].replace(to_replace=[1, 0], value=["Yes", "No"])
data["hasChangingTable"] = data["hasChangingTable"].replace(to_replace=[1, 0], value=["Yes", "No/Unknown"])
data["hasUrinal"] = data["hasUrinal"].replace(to_replace=[1, 0], value=["Yes", "No"])

# %%
data['Latitude']=data['Latitude'].str.replace(',', '.').astype(np.float64)
data['Longitude']=data['Longitude'].str.replace(',', '.').astype(np.float64)
#data['Price']=data['Price'].str.replace(',', '.').astype(np.float64)

# %%
data["LabelID"] = data["LabelID"].replace(to_replace=[1, 2,3,4,5,6], value=["Berliner Toilette", "City Toilette","WC-Center","Café Achteck","weitere ÖTs (z.B. Sanitärcontainer)","Toilette nicht von Wall"])

# %%
data.head()
# Out:
# 2   LavatoryID                                        Description    City  \
# 3  Wall_101003  Toilette Ottmachauer Steig (oberhalb Badestell...  Berlin
# 4  Wall_112911                                  Toilette Uferweg   Berlin
# 5  Wall_115753                           Toilette Am Kiesteich 50  Berlin
# 6  Wall_116738                              Wall CT, Hubertusdamm  Berlin
# 7  Wall_116739                                Wall CT, Lindenufer  Berlin
#
# 2                                             Street opening_hours  \
# 3            Krumme Lanke, Quermatenweg   (0-24 Uhr)    0:00-24:00
# 4  Schlachtensee , Am Schlachtensee ggü. 145  (0-...    0:00-24:00
# 5                            Spektepark   (0-24 Uhr)    0:00-24:00
# 6                     Hubertusdamm ggü. 7 (0-24 Uhr)    0:00-24:00
# 7                      Lindenufer ggü. 10 (0-24 Uhr)    0:00-24:00
#
# 2                               street_address PostalCode      Country  \
# 3                Krumme Lanke, Quermatenweg         14109  Deutschland
# 4  Schlachtensee , Am Schlachtensee ggü. 145        14129  Deutschland
# 5                                Spektepark         13589  Deutschland
# 6                         Hubertusdamm ggü. 7       13125  Deutschland
# 7                          Lindenufer ggü. 10       13597  Deutschland
#
# 2  Longitude   Latitude isOwnedByWall isHandicappedAccessible Price  \
# 3  13.240575  52.453581           Yes                      No  0,00
# 4  13.199229  52.436507           Yes                      No  0,00
# 5  13.164859  52.548840           Yes                      No  0,00
# 6  13.471198  52.615671           Yes                     Yes  0,50
# 7  13.207764  52.537351           Yes                     Yes  0,50
#
# 2 canBePayedWithCoins canBePayedInApp canBePayedWithNFC hasChangingTable  \
# 3                  No              No                No       No/Unknown
# 4                  No              No                No       No/Unknown
# 5                  No              No                No       No/Unknown
# 6                 Yes             Yes               Yes              Yes
# 7                 Yes             Yes               Yes              Yes
#
# 2                              LabelID hasUrinal
# 3  weitere ÖTs (z.B. Sanitärcontainer)        No
# 4  weitere ÖTs (z.B. Sanitärcontainer)        No
# 5  weitere ÖTs (z.B. Sanitärcontainer)        No
# 6                    Berliner Toilette       Yes
# 7                    Berliner Toilette        No

# %%
#data.to_csv('C:/Users/Rashmi Dsouza/Desktop/TechLabs/Project/Data/draft_peedom.csv')

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.countplot(data['isHandicappedAccessible'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.countplot(data['Price'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.countplot(data['canBePayedWithCoins'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.countplot(data['canBePayedInApp'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.countplot(data['hasChangingTable'], ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.countplot(data['hasUrinal'], ax=ax)
plt.show()

# %%
# Adding placeholder google ratings
data['google_rating_rank']=np.random.randint(1,6,size=len(data.index))

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.countplot(data['google_rating_rank'], ax=ax)
plt.show()

# %%
# Adding weights depending on the feature importance
mapping = {'Yes': 1, 'No': 0}

pricing = {'0.00': 5,'0.10':4, '0.20':3 ,'0.50':2}

#distancing = {}

# Assigning weights to individual features and storing them in new coulmns
 
data['isHandicappedAccessible_1'] = (data['isHandicappedAccessible'].replace(mapping))*2
data['Price_1'] = (data['Price'].replace(pricing))*5
data['canBePayedWithCoins_1'] = (data['canBePayedWithCoins'].replace(mapping))*3
data['canBePayedInApp_1'] = (data['canBePayedInApp'].replace(mapping))*2
data['hasChangingTable_1'] = (data['hasChangingTable'].replace(mapping))*2
data['hasUrinal_1'] = (data['hasUrinal'].replace(mapping))*3
data['google_rating_rank_1'] =(data['google_rating_rank'])*4


#summing up weights of individual features

data['ratings'] = data[['isHandicappedAccessible_1','Price_1','canBePayedWithCoins_1','canBePayedInApp_1','hasChangingTable_1',
                    'hasUrinal_1','google_rating_rank_1']].sum(axis=1)

#Assigning the sum to rating ranging from 1-5. Example a sum of 40, is assigned between a range 30-40 
#and then the value is assigned to a rating of 4

#ranges = [0,4,10,20,40,np.inf]

#cat = ['1','2','3','4','5']

#data['ratings'] = pd.cut(data['Sum'], bins = ranges, labels = cat)

#if there are NaN values present in ratings those columns are dropped

data = data[~data['ratings'].isna()]

# %%
data
# Out:
# 2     LavatoryID                                        Description    City  \
# 3    Wall_101003  Toilette Ottmachauer Steig (oberhalb Badestell...  Berlin
# 4    Wall_112911                                  Toilette Uferweg   Berlin
# 5    Wall_115753                           Toilette Am Kiesteich 50  Berlin
# 6    Wall_116738                              Wall CT, Hubertusdamm  Berlin
# 7    Wall_116739                                Wall CT, Lindenufer  Berlin
# ..           ...                                                ...     ...
# 438      Fremd_5                          Toilette Tempelhofer Feld  Berlin
# 439      Fremd_6                          Toilette Tempelhofer Feld  Berlin
# 440      Fremd_7                          Toilette Tempelhofer Feld  Berlin
# 441      Fremd_8                          Toilette Tempelhofer Feld  Berlin
# 442      Fremd_9                          Toilette Tempelhofer Feld  Berlin
#
# 2                                               Street opening_hours  \
# 3              Krumme Lanke, Quermatenweg   (0-24 Uhr)    0:00-24:00
# 4    Schlachtensee , Am Schlachtensee ggü. 145  (0-...    0:00-24:00
# 5                              Spektepark   (0-24 Uhr)    0:00-24:00
# 6                       Hubertusdamm ggü. 7 (0-24 Uhr)    0:00-24:00
# 7                        Lindenufer ggü. 10 (0-24 Uhr)    0:00-24:00
# ..                                                 ...           ...
# 438                                   Tempelhofer Feld           NaN
# 439                                   Tempelhofer Feld           NaN
# 440                                   Tempelhofer Feld           NaN
# 441                                   Tempelhofer Feld           NaN
# 442                                   Tempelhofer Feld           NaN
#
# 2                                 street_address PostalCode      Country  \
# 3                  Krumme Lanke, Quermatenweg         14109  Deutschland
# 4    Schlachtensee , Am Schlachtensee ggü. 145        14129  Deutschland
# 5                                  Spektepark         13589  Deutschland
# 6                           Hubertusdamm ggü. 7       13125  Deutschland
# 7                            Lindenufer ggü. 10       13597  Deutschland
# ..                                           ...        ...          ...
# 438                             Tempelhofer Feld      12049  Deutschland
# 439                             Tempelhofer Feld      12049  Deutschland
# 440                             Tempelhofer Feld      12101  Deutschland
# 441                             Tempelhofer Feld      10965  Deutschland
# 442                             Tempelhofer Feld      10965  Deutschland
#
# 2    Longitude   Latitude  ... hasUrinal google_rating_rank  \
# 3    13.240575  52.453581  ...        No                  5
# 4    13.199229  52.436507  ...        No                  4
# 5    13.164859  52.548840  ...        No                  1
# 6    13.471198  52.615671  ...       Yes                  1
# 7    13.207764  52.537351  ...        No                  5
# ..         ...        ...  ...       ...                ...
# 438  13.417550  52.476810  ...        No                  1
# 439  13.417660  52.470190  ...        No                  3
# 440  13.386770  52.471300  ...        No                  2
# 441  13.409950  52.479400  ...        No                  1
# 442  13.404230  52.481700  ...        No                  5
#
# 2   isHandicappedAccessible_1               Price_1 canBePayedWithCoins_1  \
# 3                           0  0,000,000,000,000,00                     0
# 4                           0  0,000,000,000,000,00                     0
# 5                           0  0,000,000,000,000,00                     0
# 6                           2  0,500,500,500,500,50                     3
# 7                           2  0,500,500,500,500,50                     3
# ..                        ...                   ...                   ...
# 438                         2  0,000,000,000,000,00                     0
# 439                         2  0,000,000,000,000,00                     0
# 440                         2  0,000,000,000,000,00                     0
# 441                         2  0,000,000,000,000,00                     0
# 442                         0  0,000,000,000,000,00                     0
#
# 2   canBePayedInApp_1    hasChangingTable_1 hasUrinal_1 google_rating_rank_1  \
# 3                   0  No/UnknownNo/Unknown           0                   20
# 4                   0  No/UnknownNo/Unknown           0                   16
# 5                   0  No/UnknownNo/Unknown           0                    4
# 6                   2                     2           3                    4
# 7                   2                     2           0                   20
# ..                ...                   ...         ...                  ...
# 438                 0  No/UnknownNo/Unknown           0                    4
# 439                 0  No/UnknownNo/Unknown           0                   12
# 440                 0  No/UnknownNo/Unknown           0                    8
# 441                 0  No/UnknownNo/Unknown           0                    4
# 442                 0  No/UnknownNo/Unknown           0                   20
#
# 2    ratings
# 3         20
# 4         16
# 5          4
# 6         14
# 7         27
# ..       ...
# 438        6
# 439       14
# 440       10
# 441        6
# 442       20
#
# [440 rows x 28 columns]

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.countplot(data['ratings'], ax=ax)
plt.title('Review Stars Countplot')
plt.show()

# %%
top_toilets=data[['LavatoryID','Description','City','Street','opening_hours','street_address','PostalCode',
       'Country','Longitude','Latitude','isOwnedByWall',
       'isHandicappedAccessible','Price','canBePayedWithCoins',
       'canBePayedInApp','canBePayedWithNFC','hasChangingTable','LabelID',
       'hasUrinal','ratings']].sort_values(by=['ratings'], ascending=False)

# %%
top_toilets
# Out:
# 2     LavatoryID                                        Description    City  \
# 96   Wall_120496                         Wall CT, Landsberger Allee  Berlin
# 231  Wall_123496                             Wall CT, Dominicusstr.  Berlin
# 236  Wall_123501                              Wall CT, Rennbahnstr.  Berlin
# 289  Wall_125237                         Wall CT, Afrikanische Str.  Berlin
# 253  Wall_123871              Wall CT, Nettelbeckplatz, Gerichtstr.  Berlin
# ..           ...                                                ...     ...
# 383    Fremd_135  Toilette Parkfriedhof Neukölln - Buckower Damm...  Berlin
# 386    Fremd_138    Toilette Friedhof Rudow - Köpenicker Straße 131  Berlin
# 391    Fremd_143                       Toilette Familienfarm Lübars  Berlin
# 403    Fremd_154  Toilette Königin-Luise-Str. 57 (Friedhof), 141...  Berlin
# 353    Wall_5389  Toilette Pfaueninselchaussee (Wasserrettungsst...  Berlin
#
# 2                                            Street opening_hours  \
# 96                   Landsberger Allee   (0-24 Uhr)    0:00-24:00
# 231                  Dominicusstr. 16-18 (0-24 Uhr)    0:00-24:00
# 236                Rennbahnstr. ggü. 1-2 (0-24 Uhr)    0:00-24:00
# 289            Afrikanische Str. ggü. 92 (0-24 Uhr)    0:00-24:00
# 253      Nettelbeckplatz, Gerichtstr. 31 (0-24 Uhr)    0:00-24:00
# ..                                              ...           ...
# 383       Parkfriedhof Neukölln - Buckower Damm 148           NaN
# 386          Friedhof Rudow - Köpenicker Straße 131           NaN
# 391                             Familienfarm Lübars           NaN
# 403  Königin-Luise-Str. 57 (Friedhof), 14195 Berlin           NaN
# 353                        Uferpromenade (0-24 Uhr)    0:00-24:00
#
# 2                               street_address PostalCode      Country  \
# 96                        Landsberger Allee         10369  Deutschland
# 231                       Dominicusstr. 16-18       10825  Deutschland
# 236                     Rennbahnstr. ggü. 1-2       13086  Deutschland
# 289                 Afrikanische Str. ggü. 92       13351  Deutschland
# 253           Nettelbeckplatz, Gerichtstr. 31       13347  Deutschland
# ..                                         ...        ...          ...
# 383  Parkfriedhof Neukölln - Buckower Damm 148     12349   Deutschland
# 386     Friedhof Rudow - Köpenicker Straße 131     12355   Deutschland
# 391                        Familienfarm Lübars      13469  Deutschland
# 403                     Königin-Luise-Str. 57       14195  Deutschland
# 353                             Uferpromenade       14109  Deutschland
#
# 2    Longitude   Latitude isOwnedByWall isHandicappedAccessible Price  \
# 96   13.470695  52.531008           Yes                     Yes  0,50
# 231  13.346706  52.482408           Yes                     Yes  0,50
# 236  13.465894  52.557197           Yes                     Yes  0,50
# 289  13.336537  52.552641           Yes                     Yes  0,50
# 253  13.368579  52.544878           Yes                     Yes  0,50
# ..         ...        ...           ...                     ...   ...
# 383  13.432548  52.431152            No                      No  0,00
# 386  13.503957  52.420983            No                      No  0,00
# 391  13.367541  52.608066            No                      No  0,00
# 403  13.286124  52.458897            No                      No  0,00
# 353  13.129417  52.429389           Yes                      No  0,00
#
# 2   canBePayedWithCoins canBePayedInApp canBePayedWithNFC hasChangingTable  \
# 96                  Yes             Yes               Yes       No/Unknown
# 231                 Yes             Yes               Yes       No/Unknown
# 236                 Yes             Yes               Yes              Yes
# 289                 Yes             Yes               Yes              Yes
# 253                 Yes             Yes               Yes              Yes
# ..                  ...             ...               ...              ...
# 383                  No              No                No       No/Unknown
# 386                  No              No                No       No/Unknown
# 391                  No              No                No       No/Unknown
# 403                  No              No                No       No/Unknown
# 353                  No              No                No       No/Unknown
#
# 2                                LabelID hasUrinal  ratings
# 96                     Berliner Toilette       Yes       30
# 231                    Berliner Toilette       Yes       30
# 236                    Berliner Toilette       Yes       30
# 289                    Berliner Toilette       Yes       30
# 253                    Berliner Toilette       Yes       30
# ..                                   ...       ...      ...
# 383              Toilette nicht von Wall        No        4
# 386              Toilette nicht von Wall        No        4
# 391              Toilette nicht von Wall        No        4
# 403              Toilette nicht von Wall        No        4
# 353  weitere ÖTs (z.B. Sanitärcontainer)        No        4
#
# [440 rows x 20 columns]

# %%
top_toilets.to_csv('C:/Users/Rashmi Dsouza/Desktop/TechLabs/Project/Data/top_toilets.csv')
